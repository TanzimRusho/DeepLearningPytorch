# %% [markdown]
# <a href="https://colab.research.google.com/github/TanzimRusho/DeepLearningPytorch/blob/master/first_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# first neural network in PyTorch
x, y = get_data()  # x - represents training data, y - represents target variables

w, b = get_weights()  # w, b - Learnable parameters

for i  in range(500):
    y_prediction = simple_network(x)  # function which computes wx + b
    loss = loss_fn (y, y_prediction)  # calculates sum of the squared differences of y and y_prediction
    
if i % 50 == 0:
    print(loss)
    optimize(learning_rate)  # adjust w, b to minimize the loss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5e7eca0b50ff> in <module>()
# ----> 1 x, y = get_data()  # x - represents training data, y - represents target variables
#       2
#       3 w, b = get_weights()  # w, b - Learnable parameters
#       4
#       5 for i  in range(500):
#
# NameError: name 'get_data' is not defined

# %%
import torch

x = torch.rand(10)
x.size()
# Out:
# torch.Size([10])

# %%
temp = torch.FloatTensor([23,24,24.5,26,27.2,23])
temp.size()
# Out:
# torch.Size([6])

# %%
import sklearn
from sklearn.datasets import load_boston

boston = load_boston()
boston_tensor = torch.from_numpy(boston.data)
boston_tensor.size()
# Out:
# torch.Size([506, 13])

# %%
boston_tensor[:2]
# Out:
# tensor([[6.3200e-03, 1.8000e+01, 2.3100e+00, 0.0000e+00, 5.3800e-01, 6.5750e+00,
#          6.5200e+01, 4.0900e+00, 1.0000e+00, 2.9600e+02, 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, 0.0000e+00, 4.6900e-01, 6.4210e+00,
#          7.8900e+01, 4.9671e+00, 2.0000e+00, 2.4200e+02, 1.7800e+01, 3.9690e+02,
#          9.1400e+00]], dtype=torch.float64)

# %% [markdown]
# file:///home/chronos/u-80ea4d2ea793d48c5fbf5965dc7a2a42ed8c0ad3/MyFiles/Downloads/4.jpg

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import glob
glob.glob('/content/drive/My Drive/deep_learning_with_PyTorch/data/*')
# Out:
# ['/content/drive/My Drive/deep_learning_with_PyTorch/data/4.jpg']

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

file_path = '/content/drive/My Drive/deep_learning_with_PyTorch/data/4.jpg'

pic = np.array(Image.open(file_path).resize((224,224)))
pic_tensor = torch.from_numpy(pic)
pic_tensor.size()

plt.imshow(pic)

# %%
sales = torch.FloatTensor([1000.0,323.2,333.4,444.5,1000.0,323.2,333.2,444.5,1000.0,323.2,333.4,444.5])

print(sales[:5])

print(sales[:-1])
# Out:
# tensor([1000.0000,  323.2000,  333.4000,  444.5000, 1000.0000])
# tensor([1000.0000,  323.2000,  333.4000,  444.5000, 1000.0000,  323.2000,
#          333.2000,  444.5000, 1000.0000,  323.2000,  333.4000])

# %%
sales = torch.eye(3,3)
sales[0,1]
# Out:
# tensor(0.)

# %%
plt.imshow(pic_tensor[:,:,0].numpy())

# %%
plt.imshow(pic_tensor[0:75,0:200,0].numpy())
